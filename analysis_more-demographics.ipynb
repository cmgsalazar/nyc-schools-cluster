# %% [markdown]
# # Exploring demographic further
#
# After identifying school clusters based on race/ethnicity, I'm curious to see the makeup of these schools based on other demographic buckets, e.g., language learners, students with disabilities.

# %%
import pandas as pd

# %%
df = pd.read_csv("output/clustered-2024.csv")

# %%
cols_to_use = [ "DBN", "Year", "% Students with Disabilities", "% English Language Learners",
              "% Poverty", "Economic Need Index" ]
demographics_df = pd.read_excel("data/demographic-snapshot-2020-21-to-2024-25-public.xlsx", sheet_name="School", usecols=cols_to_use)

# %%
demographics_df = demographics_df[demographics_df["Year"] == "2024-25"]
demographics_df.drop("Year", axis=1, inplace=True)

# %%
merged_df = df.merge(demographics_df, on="DBN", how="left")
merged_df.sample(3)
# Out:
#          DBN                            School Name     Year  \
# 1570  75M138                               P.S. 138  2024-25
# 139   02M600  The High School of Fashion Industries  2024-25
# 739   15K124              P.S. 124 Silas B. Dutcher  2024-25
#
#       Total Enrollment  % Asian and Pacific Islander   % Black  % Hispanic  \
# 1570               709                      0.028209  0.277856    0.630465
# 139               1446                      0.040111  0.286999    0.593361
# 739                307                      0.035831  0.231270    0.543974
#
#       % Multi-Racial  % Native American   % White  \
# 1570        0.009873           0.004231  0.049365
# 139         0.011065           0.008990  0.052559
# 739         0.068404           0.003257  0.114007
#
#       % Missing Race/Ethnicity Data Borough  kmeans_label  \
# 1570                       0.000000       M             1
# 139                        0.006916       M             1
# 739                        0.003257       K             1
#
#       % Students with Disabilities  % English Language Learners % Poverty  \
# 1570                      0.991537                     0.282087  0.944993
# 139                       0.181189                     0.018672  0.802213
# 739                       0.244300                     0.195440  0.807818
#
#      Economic Need Index
# 1570           Above 95%
# 139             0.787224
# 739             0.820345

# %%
merged_df.to_csv("output/other-demographics-2024.csv", encoding="UTF-8", index=False)

# %% [markdown]
# ## Students with disabilities

# %%
disabilities = merged_df.groupby("kmeans_label")["% Students with Disabilities"].agg(["mean", "min", "max"])
disabilities.T.style.format("{:.1%}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_783e1">
#   <thead>
#     <tr>
#       <th class="index_name level0" >kmeans_label</th>
#       <th id="T_783e1_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_783e1_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_783e1_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_783e1_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_783e1_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_783e1_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_783e1_row0_col0" class="data row0 col0" >18.0%</td>
#       <td id="T_783e1_row0_col1" class="data row0 col1" >31.0%</td>
#       <td id="T_783e1_row0_col2" class="data row0 col2" >22.5%</td>
#       <td id="T_783e1_row0_col3" class="data row0 col3" >24.8%</td>
#       <td id="T_783e1_row0_col4" class="data row0 col4" >22.0%</td>
#     </tr>
#     <tr>
#       <th id="T_783e1_level0_row1" class="row_heading level0 row1" >min</th>
#       <td id="T_783e1_row1_col0" class="data row1 col0" >0.3%</td>
#       <td id="T_783e1_row1_col1" class="data row1 col1" >0.1%</td>
#       <td id="T_783e1_row1_col2" class="data row1 col2" >1.2%</td>
#       <td id="T_783e1_row1_col3" class="data row1 col3" >5.9%</td>
#       <td id="T_783e1_row1_col4" class="data row1 col4" >2.0%</td>
#     </tr>
#     <tr>
#       <th id="T_783e1_level0_row2" class="row_heading level0 row2" >max</th>
#       <td id="T_783e1_row2_col0" class="data row2 col0" >100.0%</td>
#       <td id="T_783e1_row2_col1" class="data row2 col1" >100.0%</td>
#       <td id="T_783e1_row2_col2" class="data row2 col2" >52.8%</td>
#       <td id="T_783e1_row2_col3" class="data row2 col3" >100.0%</td>
#       <td id="T_783e1_row2_col4" class="data row2 col4" >100.0%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Note: There are 20 schools where `merged_df["% Students with Disabilities"] == 1]`. Fifteen of these are from Cluster 1.

# %%
merged_df[merged_df["% Students with Disabilities"] == 1][["kmeans_label", "School Name"]].sort_values(by="kmeans_label")
# Out:
#       kmeans_label                            School Name
# 1578             0                              P.S. Q004
# 1551             1                              P.S. K053
# 1610             1                              P.S. X811
# 1606             1                              P.S. X643
# 1605             1                              P.S. X596
# 1602             1                              P.S. X188
# 1600             1                              P.S. X176
# 1597             1       P.S. X012 Lewis and Clark School
# 1590             1                              P.S. Q811
# 1588             1             John F. Kennedy Jr. School
# 1584             1                              P.S. Q233
# 1577             1       P.S. M811 - Mickey Mantle School
# 1568             1               P.S. M079 - Horan School
# 1557             1          P.S. K369 - Coy L. Cox School
# 1727             1  NYC Autism Charter School East Harlem
# 1854             1        NYC Autism Charter School Bronx
# 1552             3                              P.S. K077
# 1593             4   The David Marquis School of the Arts
# 1560             4        P.S. 372 -The Children's School
# 1555             4                              P.S. K231

# %%
merged_df.groupby("kmeans_label")["% Students with Disabilities"].std().T
# Out:
# kmeans_label
# 0    0.119135
# 1    0.216227
# 2    0.073837
# 3    0.135928
# 4    0.147033
# Name: % Students with Disabilities, dtype: float64

# %% [markdown]
# Observations: Cluster 1 has the highest mean, and Cluster 0 has the lowest mean. Meaning, Cluster 1 may likely have a higher share of its schools population as students with disabilities.

# %% [markdown]
# ## English language learners

# %%
ell = merged_df.groupby("kmeans_label")["% English Language Learners"].agg(["mean", "min", "max"])
ell.T.style.format("{:.1%}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_398f0">
#   <thead>
#     <tr>
#       <th class="index_name level0" >kmeans_label</th>
#       <th id="T_398f0_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_398f0_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_398f0_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_398f0_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_398f0_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_398f0_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_398f0_row0_col0" class="data row0 col0" >19.4%</td>
#       <td id="T_398f0_row0_col1" class="data row0 col1" >16.3%</td>
#       <td id="T_398f0_row0_col2" class="data row0 col2" >28.6%</td>
#       <td id="T_398f0_row0_col3" class="data row0 col3" >9.6%</td>
#       <td id="T_398f0_row0_col4" class="data row0 col4" >11.4%</td>
#     </tr>
#     <tr>
#       <th id="T_398f0_level0_row1" class="row_heading level0 row1" >min</th>
#       <td id="T_398f0_row1_col0" class="data row1 col0" >0.0%</td>
#       <td id="T_398f0_row1_col1" class="data row1 col1" >0.0%</td>
#       <td id="T_398f0_row1_col2" class="data row1 col2" >0.0%</td>
#       <td id="T_398f0_row1_col3" class="data row1 col3" >0.0%</td>
#       <td id="T_398f0_row1_col4" class="data row1 col4" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_398f0_level0_row2" class="row_heading level0 row2" >max</th>
#       <td id="T_398f0_row2_col0" class="data row2 col0" >81.6%</td>
#       <td id="T_398f0_row2_col1" class="data row2 col1" >88.0%</td>
#       <td id="T_398f0_row2_col2" class="data row2 col2" >100.0%</td>
#       <td id="T_398f0_row2_col3" class="data row2 col3" >36.7%</td>
#       <td id="T_398f0_row2_col4" class="data row2 col4" >86.2%</td>
#     </tr>
#   </tbody>
# </table>

# %%
merged_df.groupby("kmeans_label")["% English Language Learners"].std().T
# Out:
# kmeans_label
# 0    0.137138
# 1    0.114132
# 2    0.183837
# 3    0.067964
# 4    0.116825
# Name: % English Language Learners, dtype: float64

# %% [markdown]
# Observations: Cluster 2 has the highest mean (more than a quarter), and Cluster 3 has the lowest. Meaning, schools under Cluster 2 has the highest share of its student population as English language learners. Cluster 3 has the lowest max percentage, with a very low std. Among the clusters, it could have the least need for English language learning programs.

# %% [markdown]
# ## Poverty and economic need

# %%
merged_df["% Poverty"] = merged_df["% Poverty"].astype(str).str.replace("Above 95%", "0.951")
merged_df["% Poverty"] = pd.to_numeric(merged_df["% Poverty"], errors="coerce")

poverty = merged_df.groupby("kmeans_label")["% Poverty"].agg(["mean", "min", "max"])
poverty.T.style.format("{:.1%}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_0971c">
#   <thead>
#     <tr>
#       <th class="index_name level0" >kmeans_label</th>
#       <th id="T_0971c_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_0971c_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_0971c_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_0971c_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_0971c_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0971c_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_0971c_row0_col0" class="data row0 col0" >73.4%</td>
#       <td id="T_0971c_row0_col1" class="data row0 col1" >87.4%</td>
#       <td id="T_0971c_row0_col2" class="data row0 col2" >89.6%</td>
#       <td id="T_0971c_row0_col3" class="data row0 col3" >85.0%</td>
#       <td id="T_0971c_row0_col4" class="data row0 col4" >53.0%</td>
#     </tr>
#     <tr>
#       <th id="T_0971c_level0_row1" class="row_heading level0 row1" >min</th>
#       <td id="T_0971c_row1_col0" class="data row1 col0" >9.1%</td>
#       <td id="T_0971c_row1_col1" class="data row1 col1" >55.7%</td>
#       <td id="T_0971c_row1_col2" class="data row1 col2" >57.2%</td>
#       <td id="T_0971c_row1_col3" class="data row1 col3" >30.7%</td>
#       <td id="T_0971c_row1_col4" class="data row1 col4" >5.6%</td>
#     </tr>
#     <tr>
#       <th id="T_0971c_level0_row2" class="row_heading level0 row2" >max</th>
#       <td id="T_0971c_row2_col0" class="data row2 col0" >95.1%</td>
#       <td id="T_0971c_row2_col1" class="data row2 col1" >95.1%</td>
#       <td id="T_0971c_row2_col2" class="data row2 col2" >95.1%</td>
#       <td id="T_0971c_row2_col3" class="data row2 col3" >95.1%</td>
#       <td id="T_0971c_row2_col4" class="data row2 col4" >94.5%</td>
#     </tr>
#   </tbody>
# </table>

# %%
merged_df.groupby("kmeans_label")["% Poverty"].std().T
# Out:
# kmeans_label
# 0    0.168271
# 1    0.084655
# 2    0.072965
# 3    0.091757
# 4    0.228122
# Name: % Poverty, dtype: float64

# %%
merged_df["Economic Need Index"] = merged_df["Economic Need Index"].astype(str).str.replace("Above 95%", "0.951")
merged_df["Economic Need Index"] = pd.to_numeric(merged_df["Economic Need Index"], errors="coerce")

economic_need = merged_df.groupby("kmeans_label")["Economic Need Index"].agg(["mean", "min", "max"])
economic_need.T.style.format("{:.1%}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_c1504">
#   <thead>
#     <tr>
#       <th class="index_name level0" >kmeans_label</th>
#       <th id="T_c1504_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_c1504_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_c1504_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_c1504_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_c1504_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1504_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_c1504_row0_col0" class="data row0 col0" >69.3%</td>
#       <td id="T_c1504_row0_col1" class="data row0 col1" >87.8%</td>
#       <td id="T_c1504_row0_col2" class="data row0 col2" >89.1%</td>
#       <td id="T_c1504_row0_col3" class="data row0 col3" >83.7%</td>
#       <td id="T_c1504_row0_col4" class="data row0 col4" >52.4%</td>
#     </tr>
#     <tr>
#       <th id="T_c1504_level0_row1" class="row_heading level0 row1" >min</th>
#       <td id="T_c1504_row1_col0" class="data row1 col0" >13.0%</td>
#       <td id="T_c1504_row1_col1" class="data row1 col1" >47.4%</td>
#       <td id="T_c1504_row1_col2" class="data row1 col2" >54.5%</td>
#       <td id="T_c1504_row1_col3" class="data row1 col3" >38.9%</td>
#       <td id="T_c1504_row1_col4" class="data row1 col4" >6.8%</td>
#     </tr>
#     <tr>
#       <th id="T_c1504_level0_row2" class="row_heading level0 row2" >max</th>
#       <td id="T_c1504_row2_col0" class="data row2 col0" >95.1%</td>
#       <td id="T_c1504_row2_col1" class="data row2 col1" >95.1%</td>
#       <td id="T_c1504_row2_col2" class="data row2 col2" >95.1%</td>
#       <td id="T_c1504_row2_col3" class="data row2 col3" >95.1%</td>
#       <td id="T_c1504_row2_col4" class="data row2 col4" >95.1%</td>
#     </tr>
#   </tbody>
# </table>

# %%
merged_df.groupby("kmeans_label")["Economic Need Index"].std().T
# Out:
# kmeans_label
# 0    0.162325
# 1    0.083624
# 2    0.076943
# 3    0.098638
# 4    0.213386
# Name: Economic Need Index, dtype: float64

# %% [markdown]
# Observations: Cluster 4 has the lowest mean, but it also has the widest range of poverty rates among its students. This could highlight economic disparity among schools in the cluster.
#
# Cluster 0 also has a wide range of poverty rates, but its mean is relatively higher (almost three-quarters). So, this could mean more schools here serve impoverished students, than not.
#
# Cluster 1 and 2 have pretty similar aggregates.
